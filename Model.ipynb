# %%
# !pip install ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 914.9/914.9 kB 17.8 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 18.9 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [widgetsnbextension]
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-docling
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ollama
from langchain_docling.loader import DoclingLoader
model="llama3:8b"
FILE_PATH=r"C:\Users\deepa\Downloads\Resume_Y.pdf"
loader=DoclingLoader(file_path=FILE_PATH)
docs=loader.load()
# Out:
# [INFO] 2026-06-13 22:46:12,608 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-06-13 22:46:12,610 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-06-13 22:46:12,636 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\deepa\AppData\Roaming\Python\Python314\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-06-13 22:46:12,640 [RapidOCR] main.py:50: Using C:\Users\deepa\AppData\Roaming\Python\Python314\site-packages\rapidocr\models\ch_PP-OCRv4_det_mobile.pth
# [INFO] 2026-06-13 22:46:12,986 [RapidOCR] base.py:22: Using engine_name: torch
# [INFO] 2026-06-13 22:46:12,989 [RapidOCR] device_config.py:57: Using CPU device
# [INFO] 2026-06-13 22:46:12,991 [RapidOCR] download_file.py:60: File exists and is valid: C:\Users\deepa\AppData\Roaming\Python\Python314\site-packages\rapidocr\models\ch_ptocr_mobile_v2.0_cls_mobile.pth
# ...

# %%
# !pip install langchain-text-splitters
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=60)
text=text_splitter.split_documents(docs)
print(text[0])
print(text[1])
# Out:
# page_content='Profile' metadata={'source': 'C:\\Users\\deepa\\Downloads\\Resume_Y.pdf', 'dl_meta': {'schema_name': 'docling_core.transforms.chunker.DocMeta', 'version': '1.0.0', 'doc_items': [{'self_ref': '#/texts/3', 'parent': {'$ref': '#/body'}, 'children': [], 'content_layer': 'body', 'label': 'text', 'prov': [{'page_no': 1, 'bbox': {'l': 28.8, 't': 679.2134558, 'r': 593.99722694, 'b': 658.5518898772334, 'coord_origin': 'BOTTOMLEFT'}, 'charspan': [0, 239]}]}], 'headings': ['Profile'], 'origin': {'mimetype': 'application/pdf', 'binary_hash': 3342032392843527951, 'filename': 'Resume_Y.pdf'}}}
# ...

# %%
pip install langchain-huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/588.9 kB ? eta -:--:--
#    ---------------------------------------- 588.9/588.9 kB 62.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    -------------------- ------------------- 4.2/8.3 MB 23.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 21.4 MB/s  0:00:00
# ...
#
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
#    -------- ------------------------------- 1/5 [narwhals]
# ...

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="BAAI/bge-large-en-v1.5")
# Out:
# C:\Users\deepa\AppData\Roaming\Python\Python314\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\deepa\.cache\huggingface\hub\models--BAAI--bge-large-en-v1.5. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
pip install langchain-chroma
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_chroma import Chroma
vector_store=Chroma(
    collection_name="sample_RAG",
    embedding_function=embeddings,
    persist_directory="./chroma-langchain_db",
)
print(vector_store._collection.count())
# Out:
# 0

# %%
pip install langchain-community
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------  2.4/2.4 MB 23.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 15.1 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 12.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 18.4 MB/s  0:00:00
# ...
#
#    -------- ------------------------------- 1/5 [greenlet]
#    -------- ------------------------------- 1/5 [greenlet]
#    -------- ------------------------------- 1/5 [greenlet]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
#    ---------------- ----------------------- 2/5 [sqlalchemy]
# ...

# %%
from langchain_community.vectorstores.utils import filter_complex_metadata
text=filter_complex_metadata(text)
vector_store.add_documents(text)
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_25176\3557903476.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores.utils import filter_complex_metadata
# ['16cc4ff1-8b5c-43c8-aa6b-cddcba2bc53f',
#  'f28a1470-db0e-48f7-9035-1fcdb054a1aa',
#  'efd95059-770e-424f-8b97-65e7403d14fa',
#  '776a3566-e911-4214-ae03-fc718d45b296',
#  'dd3fe96d-b53d-4186-9c0c-dea039ed4b90',
#  'c76badc0-de2d-4bc2-a00f-6524b1a64568',
#  'a9dd843b-aa96-4448-9270-8e70fa8958e7',
#  '570259ee-3c11-4c86-accd-21296b4b756e',
#  '1210ca5f-e2ec-4f88-8f5a-10cbde0a2796',
#  '15f87126-6256-413a-be95-ec20b2f603ef',
#  '95d3174b-1e70-4783-a2ee-8f4a900a6110',
#  'a2be467d-844b-4513-948c-eaed23202c48',
#  '1757d6dd-3e97-4e5c-92de-6c04a1e44598',
#  '2b638219-ed36-49d3-965b-c5c728b556b4',
# ...

# %%
vector_store._collection.count()
# Out:
# 17

# %%
vector_store._collection.get(ids=['2863586c-aebe-4ea0-a138-37c5adee9295'],include=["embeddings","documents"])
# Out:
# {'ids': [],
#  'embeddings': array([], dtype=float64),
#  'documents': [],
#  'uris': None,
#  'included': ['embeddings', 'documents'],
#  'data': None,
#  'metadatas': None}

# %%
retriever=vector_store.as_retriever()

# %%
query="what is AI"
retriever_docs=retriever.invoke(query)
context="/n/n".join([doc.page_content for doc in retriever_docs])
print(context)
# Out:
# AICTE
# - Foundations of AI/n/nMicrosoft (via Edunet Foundation and AICTE) - Foundations of AI Internship (Remote)
# April-May 2025
# - Completed a 4-week internship focused on the fundamentals of Artificial Intelligence./n/n- Gained hands-on experience with AI concepts including machine learning models, data handling, and real-world applications./n/nIBM
# - Introduction to Web Development with HTML5,CSS3 and Javascript

# %%
docs=retriever.invoke("what is major branch of AI")
print(docs)
# Out:
# [Document(id='1757d6dd-3e97-4e5c-92de-6c04a1e44598', metadata={'source': 'C:\\Users\\deepa\\Downloads\\Resume_Y.pdf'}, page_content='AICTE\n- Foundations of AI'), Document(id='1210ca5f-e2ec-4f88-8f5a-10cbde0a2796', metadata={'source': 'C:\\Users\\deepa\\Downloads\\Resume_Y.pdf'}, page_content='- Gained hands-on experience with AI concepts including machine learning models, data handling, and real-world applications.'), Document(id='570259ee-3c11-4c86-accd-21296b4b756e', metadata={'source': 'C:\\Users\\deepa\\Downloads\\Resume_Y.pdf'}, page_content='Microsoft (via Edunet Foundation and AICTE) - Foundations of AI Internship (Remote)\nApril-May 2025\n- Completed a 4-week internship focused on the fundamentals of Artificial Intelligence.'), Document(id='16715fe4-89ee-458b-8057-3d00b557e25e', metadata={'source': 'C:\\Users\\deepa\\Downloads\\Resume_Y.pdf'}, page_content='Extra-Curricular Activities\n- Participated in Smart India Hackathon(SIH)\n- Participated in AppScape Designathon')]

# %%
prompt=f"""you are an intelligent RAG assistant.answer the users questions based on the any topic
context:{context}
question:{query}
"""

# %%
print(query)
print(context)
# Out:
# what is AI
# AICTE
# - Foundations of AI/n/nMicrosoft (via Edunet Foundation and AICTE) - Foundations of AI Internship (Remote)
# April-May 2025
# - Completed a 4-week internship focused on the fundamentals of Artificial Intelligence./n/n- Gained hands-on experience with AI concepts including machine learning models, data handling, and real-world applications./n/nIBM
# - Introduction to Web Development with HTML5,CSS3 and Javascript
